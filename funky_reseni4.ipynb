# %%
import cv2
import numpy as np
import load_ren_data as lrd
import matplotlib.pyplot as plt
from PIL import Image

# Načtení obrázku
img = lrd.load_data("./vzorky/salt_pepper_intensity_0.01", "./vzorky/original")[0][0]
#image = cv2.imread('./vzorky/salt_pepper_intensity_0.01/300.png', cv2.IMREAD_GRAYSCALE)
# Aplikace mediánového filtru
denoised_image = cv2.medianBlur(img, 5)  # Velikost okna je 5x5

# Uložení výsledného obrázku
#cv2.imwrite('obrazek_bez_sumu.jpg', denoised_image)

#cv2.imshow('Obrázek bez šumu', denoised_image)
#cv2.waitKey(0)  # Počká na stisknutí klávesy
#cv2.destroyAllWindows()  # Zavře okno

plt.imshow(denoised_image, cmap='gray')
plt.axis('off')  # Skryje osy
plt.show()

#plt.imshow(clean_image, cmap='gray')
#plt.axis('off')
#plt.show()
